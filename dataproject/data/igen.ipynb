# %%
import pandas as pd

import matplotlib.pyplot as plt
plt.rcParams.update({"axes.grid":True,"grid.color":"black","grid.alpha":"0.25","grid.linestyle":"--"})
plt.rcParams.update({'font.size': 14})

# %%
import os 

# Using assert to check that paths exist on computer.
assert os.path.isdir('data/')
assert os.path.isfile('data/bog1.xlsx')


# Print everything in data
os.listdir('data/')
# Out:
# ['BOG1.xlsx']

# %%
filename = 'data/BOG1.xlsx' # open the file and have a look at it
pd.read_excel(filename).head(10)
# Out:
#   Fertilitetskvotienter efter alder og tid  Unnamed: 1  Unnamed: 2  \
# 0                 Enhed: Pr. 1.000 kvinder         NaN         NaN
# 1                                      NaN     1973.00     1974.00
# 2                                    15-19       19.30       18.88
# 3                                    20-24      121.72      123.82
# 4                                    25-29      142.26      139.74
# 5                                    30-34       70.84       68.94
# 6                                    35-39       23.98       23.08
# 7                                    40-44        4.94        4.66
# 8                                    45-49        0.32        0.24
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1     1975.00     1976.00     1977.00     1978.00     1979.00     1980.00
# ...

# %%
fert = pd.read_excel(filename, skiprows=2)
fert.head(7)
# Out:
#   Unnamed: 0    1973    1974    1975    1976    1977    1978    1979    1980  \
# 0      15-19   19.30   18.88   19.70   16.80   15.98   14.48   12.94   11.98
# 1      20-24  121.72  123.82  127.66  112.58  107.36  105.08   99.28   93.54
# 2      25-29  142.26  139.74  142.84  131.64  125.76  130.00  125.04  121.82
# 3      30-34   70.84   68.94   68.38   63.36   60.54   61.94   61.14   60.64
# 4      35-39   23.98   23.08   20.92   20.84   18.70   18.84   18.50   17.94
# 5      40-44    4.94    4.66    4.08    4.04    3.42    3.20    3.28    3.22
# 6      45-49    0.32    0.24    0.18    0.18    0.16    0.14    0.14    0.16
#
#      1981  ...    2014    2015    2016    2017    2018    2019    2020  \
# 0    9.94  ...    2.40    2.28    2.52    1.84    1.60    1.30    1.12
# 1   84.36  ...   29.08   29.02   29.80   28.90   26.08   23.56   20.48
# 2  114.60  ...  102.14  102.66  107.44  104.20  101.36   99.56   97.12
# ...

# %%
fert.drop(columns=[str(i) for i in range(1973, 2010)], inplace=True)
fert.head(5)
# Out:
#   Unnamed: 0    2010    2011    2012    2013    2014    2015    2016    2017  \
# 0      15-19    3.58    3.20    3.04    2.90    2.40    2.28    2.52    1.84
# 1      20-24   37.38   33.60   32.34   29.84   29.08   29.02   29.80   28.90
# 2      25-29  114.44  106.34  105.08   99.34  102.14  102.66  107.44  104.20
# 3      30-34  139.64  131.22  129.14  126.94  126.40  130.00  133.20  131.94
# 4      35-39   65.76   62.72   62.64   60.88   63.70   64.06   68.78   67.16
#
#      2018    2019    2020    2021    2022    2023
# 0    1.60    1.30    1.12    0.90    0.72    0.78
# 1   26.08   23.56   20.48   18.98   17.08   15.40
# 2  101.36   99.56   97.12   97.68   86.82   81.52
# 3  131.90  130.76  130.62  135.60  123.10  120.40
# 4   67.96   67.94   68.54   73.30   65.44   63.66

# %%
fert.rename(columns = {'Unnamed: 0':'Age group'}, inplace=True)
fert.head(7)
# Out:
#   Age group    2010    2011    2012    2013    2014    2015    2016    2017  \
# 0     15-19    3.58    3.20    3.04    2.90    2.40    2.28    2.52    1.84
# 1     20-24   37.38   33.60   32.34   29.84   29.08   29.02   29.80   28.90
# 2     25-29  114.44  106.34  105.08   99.34  102.14  102.66  107.44  104.20
# 3     30-34  139.64  131.22  129.14  126.94  126.40  130.00  133.20  131.94
# 4     35-39   65.76   62.72   62.64   60.88   63.70   64.06   68.78   67.16
# 5     40-44   12.78   12.76   12.84   13.12   13.86   13.90   14.54   15.44
# 6     45-49    0.64    0.64    0.76    0.74    0.72    0.74    0.86    0.94
#
#      2018    2019    2020    2021    2022    2023
# 0    1.60    1.30    1.12    0.90    0.72    0.78
# 1   26.08   23.56   20.48   18.98   17.08   15.40
# 2  101.36   99.56   97.12   97.68   86.82   81.52
# 3  131.90  130.76  130.62  135.60  123.10  120.40
# 4   67.96   67.94   68.54   73.30   65.44   63.66
# 5   16.04   15.68   15.96   17.08   16.00   15.98
# ...

# %%
col_dict = {}
for i in range(2010, 2023+1): # range goes from 2008 to but not including 2018
    col_dict[str(i)] = f'fert{i}'

col_dict = {str(i) : f'fert{i}' for i in range(2010,2023+1)}
col_dict
# Out:
# {'2010': 'fert2010',
#  '2011': 'fert2011',
#  '2012': 'fert2012',
#  '2013': 'fert2013',
#  '2014': 'fert2014',
#  '2015': 'fert2015',
#  '2016': 'fert2016',
#  '2017': 'fert2017',
#  '2018': 'fert2018',
#  '2019': 'fert2019',
#  '2020': 'fert2020',
#  '2021': 'fert2021',
#  '2022': 'fert2022',
#  '2023': 'fert2023'}

# %%
fert.rename(columns = col_dict, inplace=True)
fert.head(7)
# Out:
#   Age group  fert2010  fert2011  fert2012  fert2013  fert2014  fert2015  \
# 0     15-19      3.58      3.20      3.04      2.90      2.40      2.28
# 1     20-24     37.38     33.60     32.34     29.84     29.08     29.02
# 2     25-29    114.44    106.34    105.08     99.34    102.14    102.66
# 3     30-34    139.64    131.22    129.14    126.94    126.40    130.00
# 4     35-39     65.76     62.72     62.64     60.88     63.70     64.06
# 5     40-44     12.78     12.76     12.84     13.12     13.86     13.90
# 6     45-49      0.64      0.64      0.76      0.74      0.72      0.74
#
#    fert2016  fert2017  fert2018  fert2019  fert2020  fert2021  fert2022  \
# 0      2.52      1.84      1.60      1.30      1.12      0.90      0.72
# 1     29.80     28.90     26.08     23.56     20.48     18.98     17.08
# 2    107.44    104.20    101.36     99.56     97.12     97.68     86.82
# 3    133.20    131.94    131.90    130.76    130.62    135.60    123.10
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

fert[['Age group', 'fert2010']].plot(x='Age group', y='fert2010', kind='bar', ax=axes[0, 0])
axes[0, 0].set_xlabel('Age group')
axes[0, 0].set_ylabel('Fertility rate')
axes[0, 0].set_title('Fertility Rate by Age Group (2010)')

fert[['Age group', 'fert2015']].plot(x='Age group', y='fert2015', kind='bar', ax=axes[0, 1])
axes[0, 1].set_xlabel('Age group')
axes[0, 1].set_ylabel('Fertility rate')
axes[0, 1].set_title('Fertility Rate by Age Group (2015)')

fert[['Age group', 'fert2020']].plot(x='Age group', y='fert2020', kind='bar', ax=axes[1, 0])
axes[1, 0].set_xlabel('Age group')
axes[1, 0].set_ylabel('Fertility rate')
axes[1, 0].set_title('Fertility Rate by Age Group (2020)')

fert[['Age group', 'fert2023']].plot(x='Age group', y='fert2023', kind='bar', ax=axes[1, 1])
axes[1, 1].set_xlabel('Age group')
axes[1, 1].set_ylabel('Fertility rate')
axes[1, 1].set_title('Fertility Rate by Age Group (2023)')

plt.tight_layout()
plt.show()
